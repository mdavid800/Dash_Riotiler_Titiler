# %% [markdown]
# **NetCDF open and write to file for Windographer example**

# %%
import xarray as xr

# %%
#read in NetCDF using Xarray#
#change .nc location below
dataDIR = r"C:\Users\mdavi\Downloads\lidar.z05.a0.20201008.001000.sta.a2e.nc"
DS = xr.open_dataset(dataDIR)

# show in notebook to view (this can be deleted if not required)
DS
# Out:
# <xarray.Dataset>
# Dimensions:               (height: 12, time: 144)
# Coordinates:
#   * height                (height) int64 40 60 80 90 100 ... 160 180 200 220 240
#   * time                  (time) datetime64[ns] 2020-10-08T00:10:00 ... 2020-...
# Data variables:
#     pressure              (time) float64 ...
#     wind_speed            (time, height) float64 ...
#     wind_direction        (time, height) float64 ...
#     data_availability     (time, height) float64 ...
#     qc_pressure           (time) int32 ...
#     qc_wind_speed         (time, height) int32 ...
#     qc_wind_direction     (time, height) int32 ...
#     qc_data_availability  (time, height) int32 ...
# Attributes:
#     title:             Lidar Ingest for .sta file
#     description:       Example ingest of data from a buoy stationed off the c...
#     conventions:       MHKiT-Cloud Data Standards v. 1.0
#     institution:       PNNL
#     code_url:          https://github.com/clansing/tsdat/releases/tag/1.0
# ...

# %%
#Convert from Xarray to Pandas Dataframe
df = DS.to_dataframe()
df

# %%
#Export to CSV 
df.to_csv('C:/Users/mdavi/Documents/lidar_z05_a0_20201008.csv')
